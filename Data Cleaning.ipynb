# %%
import pandas as pd

# %%
df = pd.read_csv('practice.csv')
df
# Out:
#     Class  Marks
# 0    2010   45.0
# 1    2011   45.0
# 2    2012    NaN
# 3    2013   66.0
# 4    2014   71.0
# 5    2015   81.0
# 6    2016   77.0
# 7    2017   56.0
# 8    2018   73.0
# 9    2019   66.0
# 10   2020   65.0
# 11   2010   45.0

# %%
# drop blank row
df1=df.dropna()
df1
# Out:
#     Class  Marks
# 0    2010   45.0
# 1    2011   45.0
# 3    2013   66.0
# 4    2014   71.0
# 5    2015   81.0
# 6    2016   77.0
# 7    2017   56.0
# 8    2018   73.0
# 9    2019   66.0
# 10   2020   65.0
# 11   2010   45.0

# %%
# mode
df['Marks'].mode()
# Out:
# 0    45.0
# Name: Marks, dtype: float64

# %%
# median
df['Marks'].median()
# Out:
# 66.0

# %%
# mean
df['Marks'].mean()
# Out:
# 62.72727272727273

# %%
df = pd.read_csv('practice.csv')
df
# Out:
#     Class  Marks
# 0    2010   45.0
# 1    2011   45.0
# 2    2012    NaN
# 3    2013   66.0
# 4    2014   71.0
# 5    2015   81.0
# 6    2016   77.0
# 7    2017   56.0
# 8    2018   73.0
# 9    2019   66.0
# 10   2020   65.0
# 11   2010   45.0

# %%
# Fill missing values with mean 
df = df.fillna(df.mean())
df
# Out:
#     Class      Marks
# 0    2010  45.000000
# 1    2011  45.000000
# 2    2012  62.727273
# 3    2013  66.000000
# 4    2014  71.000000
# 5    2015  81.000000
# 6    2016  77.000000
# 7    2017  56.000000
# 8    2018  73.000000
# 9    2019  66.000000
# 10   2020  65.000000
# 11   2010  45.000000

# %%
df = pd.read_csv('practice.csv')
df
# Out:
#     Class  Marks
# 0    2010   45.0
# 1    2011   45.0
# 2    2012    NaN
# 3    2013   66.0
# 4    2014   71.0
# 5    2015   81.0
# 6    2016   77.0
# 7    2017   56.0
# 8    2018   73.0
# 9    2019   66.0
# 10   2020   65.0
# 11   2010   45.0

# %%
df =df.duplicated()
df
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# dtype: bool

# %%
# drop duplicates values
df = df.drop_duplicates() 
df
# Out:
#     Class  Marks
# 0    2010   45.0
# 1    2011   45.0
# 2    2012    NaN
# 3    2013   66.0
# 4    2014   71.0
# 5    2015   81.0
# 6    2016   77.0
# 7    2017   56.0
# 8    2018   73.0
# 9    2019   66.0
# 10   2020   65.0

# %%
#fill blank value with random no
df= df.fillna(4444)
df
# Out:
#     Class   Marks
# 0    2010    45.0
# 1    2011    45.0
# 2    2012  4444.0
# 3    2013    66.0
# 4    2014    71.0
# 5    2015    81.0
# 6    2016    77.0
# 7    2017    56.0
# 8    2018    73.0
# 9    2019    66.0
# 10   2020    65.0
